# %% [markdown]
# ### Import cac thu vien can thiet
# 1. Problem defind: detection lung cancer using CNN VGG16

# %%
import numpy as np
import tensorflow as tf
import os
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Import du lieu va tien su ly du lieu
# dataset: from kaggle
# - test represent testing set
#
# - train represent training set
#
# - valid represent validation set
#
# - training set is 70%
#
# - testing set is 20%
#
# - validation set is 10%

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator # chuyen tu du lieu anh sang du lieu tensor cho keras
train_data_gen = ImageDataGenerator(rescale = 1./255, # tranh over fit
                                   validation_split = 0.2, #tỷ lệ ảnh được giữ lại làm validation. Augmentation sẽ không được áp dụng cho validation set.
                                    rotation_range = 5, #Xoay ảnh góc 
                                    width_shift_range = 0.2, #Dịch theo chiều ngang ngẫu nhiên trong một phạm vi
                                    height_shift_range = 0.2 #Dịch theo cao ngẫu nhiên trong một phạm vi nào đó
                                   ) # chuan hoa du lieu giup thuan loi cho viec huan luyen
valid_data_gen = ImageDataGenerator(rescale = 1./255,
                                   validation_split = 0.2)
test_data_gen = ImageDataGenerator(rescale = 1./255)

# %%
train_data_set = train_data_gen.flow_from_directory(directory = "./Data/train",
                                                    target_size = (224,224), # size cua input dau vao,mỗi ảnh sẽ được resized theo kích thước này.
                                                    class_mode = "categorical", #
                                                    batch_size = 64 #Số lượng ảnh được yielded từ generator cho mỗi lô batch.
                                                   )

valid_data_set = train_data_gen.flow_from_directory(directory = "./Data/valid",
                                                    target_size = (224,224),
                                                    class_mode = "categorical",
                                                    batch_size = 64
                                                    )
test_data_set = train_data_gen.flow_from_directory(directory = "./Data/test",
                                                    target_size = (224,224),
                                                    class_mode = "categorical",
                                                    batch_size = 64
                                                    )
# Out:
# Found 613 images belonging to 4 classes.
# Found 72 images belonging to 4 classes.
# Found 315 images belonging to 4 classes.

# %% [markdown]
# ### Gan nhan du lieu va su dung CNN model VGG16

# %%
labels = ["adenocarcinoma","Large cell carcinoma","normal","Squamous cell carcinoma"]

# %%
from tensorflow.keras.applications.vgg16 import VGG16
base_model = VGG16(input_shape = (224,224,3),
                   include_top = False, # bo phan softmax di,tu them cua minh vao
                  weights="imagenet")

# %%
# dong bang layer
for layer in base_model.layers:
    layer.trainable=False

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### xay dung model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout,Flatten,Dense,Activation,MaxPool2D,Conv2D,BatchNormalization

model = Sequential()
model.add(base_model)
model.add(Dropout(0.5)) # tranh overfiting du lieu hon loan
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(32,kernel_initializer="he_uniform"))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(Dropout(0.5))
model.add(Dense(32,kernel_initializer="he_uniform"))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(Dropout(0.5))
model.add(Dense(32,kernel_initializer="he_uniform"))
model.add(BatchNormalization())
model.add(Activation("relu"))
model.add(Dense(4,activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  dropout (Dropout)           (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  batch_normalization (BatchN  (None, 25088)            100352
#  ormalization)
#
#  dense (Dense)               (None, 32)                802848
#
#  batch_normalization_1 (Batc  (None, 32)               128
#  hNormalization)
#
#  activation (Activation)     (None, 32)                0
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  batch_normalization_2 (Batc  (None, 32)               128
#  hNormalization)
#
#  activation_1 (Activation)   (None, 32)                0
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  batch_normalization_3 (Batc  (None, 32)               128
#  hNormalization)
#
#  activation_2 (Activation)   (None, 32)                0
#
#  dense_3 (Dense)             (None, 4)                 132
#
# =================================================================
# Total params: 15,620,516
# Trainable params: 855,460
# Non-trainable params: 14,765,056
# _________________________________________________________________

# %%
import keras.backend as K
def f1(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
from tensorflow.keras.optimizers import Adam
model.compile(optimizer="Adam",loss="categorical_crossentropy",metrics=[tf.keras.metrics.BinaryAccuracy(name='accuracy'),
                                                                       tf.keras.metrics.Precision(name='precision'),
                                                                       tf.keras.metrics.Recall(name='recall'),  
                                                                      tf.keras.metrics.AUC(name='auc'),
                                                                        f1,])

# %%
# %time
history = model.fit(train_data_set,
                   validation_data=valid_data_set,
                   epochs = 20,
                  verbose = 1)
# Out:
# Wall time: 0 ns
# Epoch 1/20
# 10/10 [==============================] - 103s 10s/step - loss: 0.5771 - accuracy: 0.8960 - precision: 0.8469 - recall: 0.7129 - auc: 0.9441 - f1: 0.7704 - val_loss: 0.7581 - val_accuracy: 0.8542 - val_precision: 0.7885 - val_recall: 0.5694 - val_auc: 0.8976 - val_f1: 0.6458
# Epoch 2/20
# 10/10 [==============================] - 104s 10s/step - loss: 0.5350 - accuracy: 0.9017 - precision: 0.8676 - recall: 0.7162 - auc: 0.9532 - f1: 0.7813 - val_loss: 0.6667 - val_accuracy: 0.8646 - val_precision: 0.7705 - val_recall: 0.6528 - val_auc: 0.9241 - val_f1: 0.6175
# Epoch 3/20
# 10/10 [==============================] - 107s 11s/step - loss: 0.5523 - accuracy: 0.8948 - precision: 0.8487 - recall: 0.7047 - auc: 0.9489 - f1: 0.7632 - val_loss: 0.7044 - val_accuracy: 0.8646 - val_precision: 0.7797 - val_recall: 0.6389 - val_auc: 0.9149 - val_f1: 0.7076
# Epoch 4/20
# 10/10 [==============================] - 108s 11s/step - loss: 0.4893 - accuracy: 0.9091 - precision: 0.8794 - recall: 0.7374 - auc: 0.9614 - f1: 0.7974 - val_loss: 0.6861 - val_accuracy: 0.8438 - val_precision: 0.7213 - val_recall: 0.6111 - val_auc: 0.9144 - val_f1: 0.6998
# Epoch 5/20
# 10/10 [==============================] - 108s 11s/step - loss: 0.5271 - accuracy: 0.9017 - precision: 0.8550 - recall: 0.7308 - auc: 0.9536 - f1: 0.7849 - val_loss: 0.5559 - val_accuracy: 0.8819 - val_precision: 0.8393 - val_recall: 0.6528 - val_auc: 0.9480 - val_f1: 0.7882
# Epoch 6/20
# 10/10 [==============================] - 109s 11s/step - loss: 0.5412 - accuracy: 0.9009 - precision: 0.8504 - recall: 0.7325 - auc: 0.9508 - f1: 0.7868 - val_loss: 0.5179 - val_accuracy: 0.8993 - val_precision: 0.8525 - val_recall: 0.7222 - val_auc: 0.9588 - val_f1: 0.8761
# Epoch 7/20
# 10/10 [==============================] - 111s 11s/step - loss: 0.5048 - accuracy: 0.9066 - precision: 0.8582 - recall: 0.7504 - auc: 0.9578 - f1: 0.7988 - val_loss: 0.6679 - val_accuracy: 0.8750 - val_precision: 0.8103 - val_recall: 0.6528 - val_auc: 0.9239 - val_f1: 0.6986
# Epoch 8/20
# 10/10 [==============================] - 112s 11s/step - loss: 0.4698 - accuracy: 0.9111 - precision: 0.8692 - recall: 0.7586 - auc: 0.9646 - f1: 0.8090 - val_loss: 0.6721 - val_accuracy: 0.8611 - val_precision: 0.7500 - val_recall: 0.6667 - val_auc: 0.9188 - val_f1: 0.7728
# Epoch 9/20
# 10/10 [==============================] - 111s 11s/step - loss: 0.4895 - accuracy: 0.9025 - precision: 0.8515 - recall: 0.7390 - auc: 0.9596 - f1: 0.7918 - val_loss: 0.6257 - val_accuracy: 0.8715 - val_precision: 0.7869 - val_recall: 0.6667 - val_auc: 0.9319 - val_f1: 0.7879
# Epoch 10/20
# 10/10 [==============================] - 111s 11s/step - loss: 0.4436 - accuracy: 0.9192 - precision: 0.8821 - recall: 0.7814 - auc: 0.9688 - f1: 0.8277 - val_loss: 0.7208 - val_accuracy: 0.8333 - val_precision: 0.6935 - val_recall: 0.5972 - val_auc: 0.9099 - val_f1: 0.5613
# Epoch 11/20
# 10/10 [==============================] - 112s 11s/step - loss: 0.4306 - accuracy: 0.9197 - precision: 0.8881 - recall: 0.7765 - auc: 0.9704 - f1: 0.8269 - val_loss: 0.5509 - val_accuracy: 0.8958 - val_precision: 0.8281 - val_recall: 0.7361 - val_auc: 0.9475 - val_f1: 0.8750
# Epoch 12/20
# 10/10 [==============================] - 112s 11s/step - loss: 0.5335 - accuracy: 0.8923 - precision: 0.8226 - recall: 0.7259 - auc: 0.9510 - f1: 0.7766 - val_loss: 0.6360 - val_accuracy: 0.8819 - val_precision: 0.8167 - val_recall: 0.6806 - val_auc: 0.9334 - val_f1: 0.7675
# Epoch 13/20
# 10/10 [==============================] - 117s 12s/step - loss: 0.4547 - accuracy: 0.9201 - precision: 0.8812 - recall: 0.7863 - auc: 0.9650 - f1: 0.8331 - val_loss: 0.6314 - val_accuracy: 0.8854 - val_precision: 0.7910 - val_recall: 0.7361 - val_auc: 0.9328 - val_f1: 0.7204
# Epoch 14/20
# 10/10 [==============================] - 114s 11s/step - loss: 0.4753 - accuracy: 0.9074 - precision: 0.8484 - recall: 0.7667 - auc: 0.9611 - f1: 0.8018 - val_loss: 0.5321 - val_accuracy: 0.9062 - val_precision: 0.8358 - val_recall: 0.7778 - val_auc: 0.9501 - val_f1: 0.7446
# Epoch 15/20
# 10/10 [==============================] - 113s 11s/step - loss: 0.4173 - accuracy: 0.9246 - precision: 0.8919 - recall: 0.7945 - auc: 0.9720 - f1: 0.8405 - val_loss: 0.5731 - val_accuracy: 0.8785 - val_precision: 0.8033 - val_recall: 0.6806 - val_auc: 0.9430 - val_f1: 0.7644
# Epoch 16/20
# 10/10 [==============================] - 115s 12s/step - loss: 0.4182 - accuracy: 0.9262 - precision: 0.8830 - recall: 0.8124 - auc: 0.9707 - f1: 0.8443 - val_loss: 0.6885 - val_accuracy: 0.8854 - val_precision: 0.7910 - val_recall: 0.7361 - val_auc: 0.9205 - val_f1: 0.7790
# Epoch 17/20
# 10/10 [==============================] - 113s 11s/step - loss: 0.3720 - accuracy: 0.9327 - precision: 0.9000 - recall: 0.8222 - auc: 0.9773 - f1: 0.8578 - val_loss: 0.4622 - val_accuracy: 0.9167 - val_precision: 0.8636 - val_recall: 0.7917 - val_auc: 0.9639 - val_f1: 0.6976
# Epoch 18/20
# 10/10 [==============================] - 114s 11s/step - loss: 0.4288 - accuracy: 0.9237 - precision: 0.8804 - recall: 0.8042 - auc: 0.9691 - f1: 0.8388 - val_loss: 0.5718 - val_accuracy: 0.8993 - val_precision: 0.8116 - val_recall: 0.7778 - val_auc: 0.9464 - val_f1: 0.7968
# Epoch 19/20
# 10/10 [==============================] - 114s 11s/step - loss: 0.4388 - accuracy: 0.9217 - precision: 0.8820 - recall: 0.7928 - auc: 0.9674 - f1: 0.8340 - val_loss: 0.5149 - val_accuracy: 0.9132 - val_precision: 0.8507 - val_recall: 0.7917 - val_auc: 0.9555 - val_f1: 0.7527
# Epoch 20/20
# 10/10 [==============================] - 113s 11s/step - loss: 0.4350 - accuracy: 0.9172 - precision: 0.8648 - recall: 0.7928 - auc: 0.9675 - f1: 0.8285 - val_loss: 0.5688 - val_accuracy: 0.9028 - val_precision: 0.8438 - val_recall: 0.7500 - val_auc: 0.9461 - val_f1: 0.7383

# %%
import ipywidgets as widgets

uploader = widgets.FileUpload(multi=False)

# %%
display(uploader)
# Out:
# FileUpload(value={'000117.png': {'metadata': {'name': '000117.png', 'type': 'image/png', 'size': 82091, 'lastM…

# %%
uploader.value.keys()
for key in uploader.value.keys():
    filename = key
    print(filename)
# Out:
# 000117.png

# %%
import matplotlib.image as mpimg
from tensorflow import keras
# %matplotlib inline

path = "./Data/test/"+filename
plt.imshow(mpimg.imread(path))

img=keras.preprocessing.image.load_img(path,target_size=(224,224))
x=keras.preprocessing.image.img_to_array(img)
x=np.expand_dims(x,axis=0)
images=np.vstack([x])
y_predict = model.predict(images,batch_size=10)

print(filename)
print(y_predict)
print(labels[np.argmax(y_predict)])
# Out:
# 1/1 [==============================] - 0s 159ms/step
# 000117.png
# [[0. 0. 1. 0.]]
# normal

# %%
model.evaluate(test_data_set, verbose=1)
# Out:
# 5/5 [==============================] - 49s 10s/step - loss: 0.5729 - accuracy: 0.8976 - precision: 0.8394 - recall: 0.7302 - auc: 0.9434 - f1: 0.7801
# [0.5729499459266663,
#  0.8976190686225891,
#  0.8394160866737366,
#  0.7301587462425232,
#  0.9434400200843811,
#  0.7801041603088379]
